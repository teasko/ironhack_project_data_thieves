# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 0. import data

# %%
# import imbd data
imdb = pd.read_csv("data/imbd_movies_with_rating.csv")
imdb.head()
# Out:
#       tconst titleType                primaryTitle  \
# 0  tt0016906     movie                  Frivolinas
# 1  tt0035423     movie              Kate & Leopold
# 2  tt0064322     movie    The Woman with the Knife
# 3  tt0069049     movie  The Other Side of the Wind
# 4  tt0069204     movie             Sabse Bada Sukh
#
#                 originalTitle  isAdult  startYear  runtimeMinutes  \
# 0                  Frivolinas        0       2014            80.0
# 1              Kate & Leopold        0       2001           118.0
# 2         La femme au couteau        0       2010            80.0
# 3  The Other Side of the Wind        0       2018           122.0
# 4             Sabse Bada Sukh        0       2018             NaN
#
#                    genres  avrg_rating  num_votes
# 0          Comedy,Musical          5.6       14.0
# 1  Comedy,Fantasy,Romance          6.4    75863.0
# 2          Drama,Thriller          6.6        9.0
# 3                   Drama          6.9     5218.0
# 4            Comedy,Drama          6.1       14.0

# %%
#import boxoffice data
boxoffice = pd.read_csv("data/box_offices_mojo.csv")

# %%
boxoffice.head()
# Out:
#    Unnamed: 0                   Title  Year  Worldwide     Domestic
# 0           0  Mission: Impossible II  2000  546388105  215409889.0
# 1           1               Gladiator  2000  460583960  187705427.0
# 2           2               Cast Away  2000  429632142  233632142.0
# 3           3         What Women Want  2000  374111707  182811707.0
# 4           4                Dinosaur  2000  349822765  137748063.0

# %% [markdown]
# ## 1. clean and rename

# %%
# delete unnamed column
boxoffice.drop(columns = "Unnamed: 0",inplace=True)

# %%
# rename columns
boxoffice.columns = ["title","year","worldwide","domestic"]

# %%
# clean and rename imdb
imdb.drop(columns = "originalTitle",inplace=True)
imdb.drop(columns = "titleType",inplace=True)
imdb.columns = ["imdb_id","title","isAdult","year","minutes","genres","imdb_av_rating","imdb_num_votes"]

# %%
imdb
# Out:
#           imdb_id                                              title  isAdult  \
# 0       tt0016906                                         Frivolinas        0
# 1       tt0035423                                     Kate & Leopold        0
# 2       tt0064322                           The Woman with the Knife        0
# 3       tt0069049                         The Other Side of the Wind        0
# 4       tt0069204                                    Sabse Bada Sukh        0
# ...           ...                                                ...      ...
# 226571  tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro        0
# 226572  tt9916680  De la ilusión al desconcierto: cine colombiano...        0
# 226573  tt9916706                                    Dankyavar Danka        0
# 226574  tt9916730                                             6 Gunn        0
# 226575  tt9916754                     Chico Albuquerque - Revelações        0
#
#         year  minutes                  genres  imdb_av_rating  imdb_num_votes
# 0       2014     80.0          Comedy,Musical             5.6            14.0
# 1       2001    118.0  Comedy,Fantasy,Romance             6.4         75863.0
# 2       2010     80.0          Drama,Thriller             6.6             9.0
# 3       2018    122.0                   Drama             6.9          5218.0
# 4       2018      NaN            Comedy,Drama             6.1            14.0
# ...      ...      ...                     ...             ...             ...
# 226571  2015     57.0             Documentary             NaN             NaN
# 226572  2007    100.0             Documentary             NaN             NaN
# 226573  2013      NaN                  Comedy             NaN             NaN
# 226574  2017    116.0                      \N             NaN             NaN
# 226575  2013     49.0             Documentary             NaN             NaN
#
# [226576 rows x 8 columns]

# %% [markdown]
# ## 2. check for different movies with same title

# %% [markdown]
# ### 2.1 IMDB

# %%
# title duplicates
sum(imdb["title"].value_counts()[imdb["title"].value_counts() > 1])
# Out:
# 30603

# %%
# duplicates for tile and year  
imdb["year_title"] = imdb["year"].astype(str).str.lower() + " " + imdb["title"].astype(str).str.lower()

# drop_duplicates
duplicate_year_title = list(imdb["year_title"].value_counts()[imdb["year_title"].value_counts() > 1].index)
imdb = imdb[~imdb["year_title"].isin(duplicate_year_title)]

len(duplicate_year_title)

# %%
# Out:
# 2607

# %% [markdown]
# ### 2.2 box office

# %%
# title duplicates
sum(boxoffice["title"].value_counts()[boxoffice["title"].value_counts() > 1])
# Out:
# 392

# %%
# duplicates for tile and year  
boxoffice["year_title"] = boxoffice["year"].astype(str).str.lower() + " " + boxoffice["title"].astype(str).str.lower()

# %%
duplicate_year_title = list(boxoffice["year_title"].value_counts()[boxoffice["year_title"].value_counts() > 1].index)
boxoffice = boxoffice[~boxoffice["year_title"].isin(duplicate_year_title)]
#boxoffice.drop(columns = "year_title",inplace=True)

# %%
len(duplicate_year_title)
# Out:
# 6

# %%
# restet indices
imdb.reset_index()
boxoffice.reset_index()
# Out:
#        index                         title  year  worldwide     domestic  \
# 0          0        Mission: Impossible II  2000  546388105  215409889.0
# 1          1                     Gladiator  2000  460583960  187705427.0
# 2          2                     Cast Away  2000  429632142  233632142.0
# 3          3               What Women Want  2000  374111707  182811707.0
# 4          4                      Dinosaur  2000  349822765  137748063.0
# ...      ...                           ...   ...        ...          ...
# 12482  12494  Jimi Hendrix Electric Church  2019       1818          NaN
# 12483  12495                      Game Day  2019       1624       1624.0
# 12484  12496           The Hours and Times  2019       1273       1273.0
# 12485  12497              The Untold Story  2019        790        790.0
# 12486  12498                    The Portal  2019        685          NaN
#
#                               year_title
# 0            2000 mission: impossible ii
# 1                         2000 gladiator
# 2                         2000 cast away
# 3                   2000 what women want
# 4                          2000 dinosaur
# ...                                  ...
# 12482  2019 jimi hendrix electric church
# 12483                      2019 game day
# 12484           2019 the hours and times
# 12485              2019 the untold story
# 12486                    2019 the portal
#
# [12487 rows x 6 columns]

# %% [markdown]
# ## 3. merging imdb and boxoffice

# %%
# merge
imdb_box = imdb.merge(boxoffice,on="year_title")
# rename and drop columns
imdb_box.drop(columns=["title_y","year_y"],inplace=True)
imdb_box.rename(columns = {"title_x":"title","year_x":"year"},inplace=True)
# save to csv
imdb_box.drop(columns = "year_title").to_csv("imdb_box_merge.csv")

# %%
imdb_box.drop(columns=["title_y","year_y"],inplace=True)

# %%
imdb_box.rename(columns = {"title_x":"title","year_x":"year"},inplace=True)

# %%
imdb_box.drop(columns = "year_title").to_csv("imdb_box_merge.csv")

# %%
# Out:
# 8058

# %%
# Out:
# 8058

# %% [markdown]
# ## trying with fuzzy search

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# get list of year-title from boxoffice that could not be merged
titles_in_merge = list(imdb_box["title"].values)
box_titles_notin_merge = list(boxoffice["title"][~boxoffice["title"].isin(titles_in_merge)].values)

# %%
test_df = pd.DataFrame(columns = ["box","sug_imdb_1","sug_imdb_2","sug_imdb_3"])
h_count = 1
for title in box_titles_notin_merge:
    suggestion = process.extract(title, imdb["title"], scorer=fuzz.token_sort_ratio, limit=3)
    test_df = test_df.append({"box": title
                    ,"sug_imdb_1" : suggestion[0][0]
                    ,"sug_imdb_2"  : suggestion[1][0]
                    ,"sug_imdb_3"  : suggestion[2][0]},ignore_index=True)
    h_count += 1
    if h_count > 10:
        break

# %%
process.extract("pokemon", imdb["title"], scorer=fuzz.ratio, limit=3)
# Out:
# [('Goemon', 77, 41797), ('Spoken', 77, 124345), ('Fukemon', 71, 61335)]

# %%
# with fuzz.ration
test_df
# Out:
#                                 box                        sug_imdb_1  \
# 0                         The Beach                        The Breach
# 1            Pokémon the Movie 2000              Pokémon 3: The Movie
# 2  The Exorcist 2000 Director's Cut  The Emerging Past Director's Cut
# 3                     Fantasia 2000                        Fantasia 2
# 4                    The Ninth Gate                     The Ninth Day
# 5  Cirque du Soleil: Journey of Man               Cirque du Soleil: O
# 6                        CyberWorld                         BearWorld
# 7                          Solarmax                             Solar
# 8                     Godzilla 2000                     Godzilla 2001
# 9                            Gossip                        Ghost Ship
#
#                                  sug_imdb_2                  sug_imdb_3
# 0                                The Breach                   The Bench
# 1                           K-On! The Movie           Preto The Movie 2
# 2                        The Director's Cut          The Director's Cut
# 3                                  Fantasia                    Fantasia
# 4                             Into the Game                 In the Game
# 5  Cirque du Soleil: The Mystery of Mystere  Cirque du Soleil: Hatching
# 6                                   Cyberon                  Cyber Wars
# 7                                   Alarma!                      Soorma
# 8                                  Godzilla                Dracula 2000
# 9                                     Gloss                       Yossi

# %%
# token_sort_ratio
test_df
# Out:
#                                 box                          sug_imdb
# 0                         The Beach                        The Breach
# 1            Pokémon the Movie 2000              Pokémon 3: The Movie
# 2  The Exorcist 2000 Director's Cut  The Emerging Past Director's Cut
# 3                     Fantasia 2000                        Fantasia 2
# 4                    The Ninth Gate                     The Ninth Day
# 5  Cirque du Soleil: Journey of Man               Cirque du Soleil: O
# 6                        CyberWorld                         BearWorld
# 7                          Solarmax                             Solar
# 8                     Godzilla 2000                     Godzilla 2001
# 9                            Gossip                        Ghost Ship

# %%
# Out:
# 0                                                Frivolinas
# 1                                            Kate & Leopold
# 2                                  The Woman with the Knife
# 3                                The Other Side of the Wind
# 4                                           Sabse Bada Sukh
#                                 ...
# 226571          Rodolpho Teóphilo - O Legado de um Pioneiro
# 226572    De la ilusión al desconcierto: cine colombiano...
# 226573                                      Dankyavar Danka
# 226574                                               6 Gunn
# 226575                       Chico Albuquerque - Revelações
# Name: title, Length: 221106, dtype: object

# %%
process.extract("Pokémon the Movie 2000", imdb["title"], scorer=fuzz.ratio, limit=10)
# Out:
# [('Pokémon 3: The Movie', 81, 2074),
#  ('Preto The Movie 2', 72, 182864),
#  ('Good Humor: The Movie 2001', 71, 10023),
#  ('K-On! The Movie', 70, 88018),
#  ('Momok: The Movie', 68, 69027),
#  ('Konbai the Movie', 68, 126068),
#  ('Pokémon the Movie: I Choose You!', 68, 189659),
#  ('Pokémon Heroes', 67, 11310),
#  ('Boo! The Movie', 67, 16879),
#  ('One: The Movie', 67, 26473)]

# %%
process.extract("Pokémon the Movie 2000", imdb["title"], scorer=fuzz.partial_ratio, limit=10)
# Out:
# [('O', 100, 609),
#  ('H', 100, 7496),
#  ('K', 100, 10185),
#  ('P', 100, 21509),
#  ('E', 100, 32549),
#  ('VI', 100, 35219),
#  ('Mo', 100, 35709),
#  ('Movie', 100, 39203),
#  ('M', 100, 47528),
#  ('2', 100, 52253)]

# %%
imdb.loc[609]
# Out:
# imdb_id                        tt0184791
# title                                  O
# isAdult                                0
# year                                2001
# minutes                               95
# genres            Drama,Romance,Thriller
# imdb_av_rating                       6.1
# imdb_num_votes                     18774
# year_title                         2001o
# Name: 609, dtype: object

# %%
process.extract("Pokémon the Movie 2000", imdb["title"], scorer=fuzz.token_sort_ratio, limit=1)[0][0]
# Out:
# 'Pokémon 3: The Movie'

# %%
process.extract("Pokémon the Movie 2000", imdb["title"], scorer=fuzz.token_set_ratio, limit=10)
# Out:
# [('Movie', 100, 39203),
#  ('The the the', 100, 70457),
#  ('Movie', 100, 85848),
#  ('Movie', 100, 142779),
#  ('Movie', 100, 160257),
#  ('The...', 100, 178885),
#  ('Pokémon 3: The Movie', 94, 2074),
#  ('W the Movie', 90, 64685),
#  ('The U Movie', 90, 75744),
#  ('The 4 Movie', 90, 125917)]

# %%
imdb.loc[imdb["title"] == "Pokémon 3: The Movie"]
# Out:
#         imdb_id                 title  isAdult  year  minutes  \
# 2074  tt0235679  Pokémon 3: The Movie        0  2000     93.0
#
#                           genres  imdb_av_rating  imdb_num_votes  \
# 2074  Action,Adventure,Animation             5.8         12230.0
#
#                     year_title
# 2074  2000pokémon 3: the movie

# %%
imdb.loc[2074]
# Out:
# imdb_id                            tt0235679
# title                   Pokémon 3: The Movie
# isAdult                                    0
# year                                    2000
# minutes                                   93
# genres            Action,Adventure,Animation
# imdb_av_rating                           5.8
# imdb_num_votes                         12230
# year_title          2000pokémon 3: the movie
# Name: 2074, dtype: object

# %%
titles_in_merge = list(imdb_box["title_x"].values)

# %%
boxoffice["title"][~boxoffice["title"].isin(titles_in_merge)]
# Out:
# 31                 Pokémon the Movie 2000
# 38       The Exorcist 2000 Director's Cut
# 50                          Fantasia 2000
# 70                         The Ninth Gate
# 107      Cirque du Soleil: Journey of Man
#                        ...
# 12490       I Lost Albert 2019 Re-release
# 12493                           Jihadists
# 12494        Jimi Hendrix Electric Church
# 12495                            Game Day
# 12496                 The Hours and Times
# Name: title, Length: 4145, dtype: object

# %%
imdb[["title","year"]][imdb["title"].str.contains("Pok")]
# Out:
#                                                     title  year
# 287                               Four Dogs Playing Poker  2000
# 2074                                 Pokémon 3: The Movie  2000
# 3615                                            Poklonnik  2001
# 5878                                        Pokémon 4Ever  2001
# 5992                                                Poker  2001
# ...                                                   ...   ...
# 193001  Pokemon Deo Mu-bi XY&Z Bolkenion: Gigyewangguk...  2016
# 204508                                       Poka Messiah  2016
# 209537                 Pokémon the Movie: The Power of Us  2018
# 216990                                       Prema Pokiri  2007
# 217443   Pokémon the Movie: Mewtwo Strikes Back Evolution  2019
#
# [76 rows x 2 columns]

# %% [markdown]
# ## 3. merging imdb and boxoffice

# %%
imdb_box = imdb.merge(boxoffice,on="year_title")

# %%
imdb_box
# Out:
#         imdb_id                                         title_x  isAdult  \
# 0     tt0035423                                  Kate & Leopold        0
# 1     tt0113026                                 The Fantasticks        0
# 2     tt0116748                  Karobaar: The Business of Love        0
# 3     tt0118589                                         Glitter        0
# 4     tt0118694                            In the Mood for Love        0
# ...         ...                                             ...      ...
# 8505  tt9844368                                  Out of Liberty        0
# 8506  tt9845398                              End of the Century        0
# 8507  tt9856680                 Puffs: Filmed Live Off Broadway        0
# 8508  tt9896916                              Pilgrim's Progress        0
# 8509  tt9902734  Josh Groban Bridges from Madison Square Garden        0
#
#       year_x  minutes                      genres  imdb_av_rating  \
# 0       2001    118.0      Comedy,Fantasy,Romance             6.4
# 1       2000     86.0             Musical,Romance             5.6
# 2       2000    180.0               Drama,Romance             4.5
# 3       2001    104.0         Drama,Music,Romance             2.2
# 4       2000     98.0               Drama,Romance             8.1
# ...      ...      ...                         ...             ...
# 8505    2019    111.0               Drama,Western             4.5
# 8506    2019     84.0                       Drama             7.5
# 8507    2018    118.0            Adventure,Comedy             8.6
# 8508    2019    108.0  Adventure,Animation,Family             5.2
# 8509    2019      NaN                          \N             6.9
#
#       imdb_num_votes                                         year_title  \
# 0            75863.0                                 2001kate & leopold
# 1             1086.0                                2000the fantasticks
# 2              211.0                 2000karobaar: the business of love
# 3            21033.0                                        2001glitter
# 4           111412.0                           2000in the mood for love
# ...              ...                                                ...
# 8505           213.0                                 2019out of liberty
# 8506           526.0                             2019end of the century
# 8507            17.0                2018puffs: filmed live off broadway
# 8508           294.0                             2019pilgrim's progress
# 8509             7.0  2019josh groban bridges from madison square ga...
#
#                                              title_y  year_y  worldwide  \
# 0                                     Kate & Leopold    2001   76019048
# 1                                    The Fantasticks    2000      49666
# 2                     Karobaar: The Business of Love    2000      45200
# 3                                            Glitter    2001    5271666
# 4                               In the Mood for Love    2000   12854953
# ...                                              ...     ...        ...
# 8505                                  Out of Liberty    2019     265279
# 8506                              End of the Century    2019      64880
# 8507                 Puffs: Filmed Live Off Broadway    2018     464483
# 8508                              Pilgrim's Progress    2019    3173282
# 8509  Josh Groban Bridges from Madison Square Garden    2019     315173
#
#         domestic
# 0     47121859.0
# 1        49666.0
# 2        45200.0
# 3      4274407.0
# 4      2738980.0
# ...          ...
# 8505    265279.0
# 8506     64880.0
# 8507    464483.0
# 8508   1294596.0
# 8509    315173.0
#
# [8510 rows x 13 columns]

# %%
imbd[imbd["primaryTitle"]=="Homecoming"]
# Out:
#             tconst titleType primaryTitle         originalTitle  isAdult  \
# 14280    tt0378057     movie   Homecoming            Homecoming        0
# 15852    tt0392121     movie   Homecoming            Homecoming        0
# 18291    tt0418735     movie   Homecoming            Homecoming        0
# 20175    tt0436399     movie   Homecoming            Homecoming        0
# 46910    tt1093366     movie   Homecoming            Homecoming        0
# 50747   tt11289634     movie   Homecoming            Homecoming        0
# 51438    tt1135500     movie   Homecoming            Homecoming        0
# 74360    tt1618376     movie   Homecoming            Homecoming        0
# 80360    tt1753913     movie   Homecoming           Hômukamingu        0
# 81824    tt1779070     movie   Homecoming            Homecoming        0
# 87989    tt1908504     movie   Homecoming            Homecoming        0
# 88669    tt1929260     movie   Homecoming      HaShiva HaBayita        0
# 88927    tt1935146     movie   Homecoming            Homecoming        0
# 98693    tt2176070     movie   Homecoming            Homecoming        0
# 106610   tt2365416     movie   Homecoming            Homecoming        0
# 109932   tt2458398     movie   Homecoming            Homecoming        0
# 128831   tt3358304     movie   Homecoming  Elämältä kaiken sain        0
# 149434   tt4346320     movie   Homecoming            Homecoming        0
# 162743   tt5116212     movie   Homecoming            Homecoming        0
# 173270   tt5707716     movie   Homecoming            Homecoming        0
# 184006   tt6321136     movie   Homecoming            Homecoming        0
# 205400   tt7768382     movie   Homecoming            Homecoming        0
# 211001   tt8238416     movie   Homecoming            Homecoming        0
# 219072   tt9010890     movie   Homecoming            Homecoming        1
#
#         startYear  runtimeMinutes                   genres  avrg_rating  \
# 14280        2004             NaN              Documentary          8.6
# 15852        2003           100.0                    Drama          5.3
# 18291        2005           109.0                    Drama          7.4
# 20175        2004           104.0                    Drama          6.9
# 46910        2005            90.0                    Drama          5.4
# 50747        2019             NaN                    Drama          NaN
# 51438        2009            88.0       Drama,Horror,Sport          5.3
# 74360        2011             NaN             Comedy,Drama          7.2
# 80360        2011            93.0                   Comedy          6.0
# 81824        2010            46.0      Comedy,Drama,Family          NaN
# 87989        2011            93.0                   Comedy          5.6
# 88669        2010            60.0  Documentary,Family,News          NaN
# 88927        2011             NaN                    Drama          NaN
# 98693        2012           110.0             Drama,Family          8.6
# 106610       2012            96.0     Comedy,Drama,Romance          7.1
# 109932       2014            99.0                 Thriller          5.0
# 128831       2015           103.0             Comedy,Drama          5.2
# 149434       2015           116.0           Comedy,Mystery          7.6
# 162743       2016            90.0     Comedy,Drama,Mystery          8.0
# 173270       2015            95.0                    Drama          NaN
# 184006       2016           123.0            Drama,Musical          NaN
# 205400       2017            24.0        Documentary,Drama          NaN
# 211001       2017            15.0              Documentary          NaN
# 219072       2017            87.0                    Adult          NaN
#
#         num_votes
# 14280        18.0
# 15852        16.0
# 18291        36.0
# 20175        44.0
# 46910         5.0
# 50747         NaN
# 51438      4054.0
# 74360        42.0
# 80360         5.0
# 81824         NaN
# 87989        46.0
# 88669         NaN
# 88927         NaN
# 98693        13.0
# 106610       33.0
# 109932       24.0
# 128831      333.0
# 149434       12.0
# 162743        8.0
# 173270        NaN
# 184006        NaN
# 205400        NaN
# 211001        NaN
# 219072        NaN

# %%
duplicate_titles = list(imbd["primaryTitle"].value_counts()[imbd["primaryTitle"].value_counts() > 1].index)

# %%
imbd_no_dup_titles = imbd[~imbd["primaryTitle"].isin(duplicate_titles)].copy()

# %%
imbd_no_dup_titles["primaryTitle"].value_counts()
# Out:
# 195973

# %%
imbd
# Out:
#            tconst titleType  \
# 0       tt0016906     movie
# 1       tt0035423     movie
# 2       tt0064322     movie
# 3       tt0069049     movie
# 4       tt0069204     movie
# ...           ...       ...
# 226571  tt9916622     movie
# 226572  tt9916680     movie
# 226573  tt9916706     movie
# 226574  tt9916730     movie
# 226575  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                              Frivolinas
# 1                                          Kate & Leopold
# 2                                The Woman with the Knife
# 3                              The Other Side of the Wind
# 4                                         Sabse Bada Sukh
# ...                                                   ...
# 226571        Rodolpho Teóphilo - O Legado de um Pioneiro
# 226572  De la ilusión al desconcierto: cine colombiano...
# 226573                                    Dankyavar Danka
# 226574                                             6 Gunn
# 226575                     Chico Albuquerque - Revelações
#
#                                             originalTitle  isAdult  startYear  \
# 0                                              Frivolinas        0       2014
# 1                                          Kate & Leopold        0       2001
# 2                                     La femme au couteau        0       2010
# 3                              The Other Side of the Wind        0       2018
# 4                                         Sabse Bada Sukh        0       2018
# ...                                                   ...      ...        ...
# 226571        Rodolpho Teóphilo - O Legado de um Pioneiro        0       2015
# 226572  De la ilusión al desconcierto: cine colombiano...        0       2007
# 226573                                    Dankyavar Danka        0       2013
# 226574                                             6 Gunn        0       2017
# 226575                     Chico Albuquerque - Revelações        0       2013
#
#         runtimeMinutes                  genres  avrg_rating  num_votes
# 0                 80.0          Comedy,Musical          5.6       14.0
# 1                118.0  Comedy,Fantasy,Romance          6.4    75863.0
# 2                 80.0          Drama,Thriller          6.6        9.0
# 3                122.0                   Drama          6.9     5218.0
# 4                  NaN            Comedy,Drama          6.1       14.0
# ...                ...                     ...          ...        ...
# 226571            57.0             Documentary          NaN        NaN
# 226572           100.0             Documentary          NaN        NaN
# 226573             NaN                  Comedy          NaN        NaN
# 226574           116.0                      \N          NaN        NaN
# 226575            49.0             Documentary          NaN        NaN
#
# [226576 rows x 10 columns]

# %%
imdb_box_merge= imbd_no_dup_titles.merge(boxoffice,left_on="primaryTitle",right_on="Title")

# %%
sum(boxoffice["Title"].value_counts()>1)
# Out:
# 195

# %%
sum(imdb_box_merge["Title"].value_counts()>1)
# Out:
# 10

# %%
sum(~imdb_box_merge["avrg_rating"].isna())
# Out:
# 8953

# %%
imdb_box_merge
# Out:
#          tconst titleType                                       primaryTitle  \
# 0     tt0035423     movie                                     Kate & Leopold
# 1     tt0100275     movie                           The Wandering Soap Opera
# 2     tt0113026     movie                                    The Fantasticks
# 3     tt0116748     movie                     Karobaar: The Business of Love
# 4     tt0118589     movie                                            Glitter
# ...         ...       ...                                                ...
# 9001  tt9825006     movie                                Avant qu'on explose
# 9002  tt9826484     movie  Trinity Seven The Movie 2: Heavens Library & C...
# 9003  tt9844368     movie                                     Out of Liberty
# 9004  tt9856680     movie                    Puffs: Filmed Live Off Broadway
# 9005  tt9902734     movie     Josh Groban Bridges from Madison Square Garden
#
#                                        originalTitle  isAdult  startYear  \
# 0                                     Kate & Leopold        0       2001
# 1                              La Telenovela Errante        0       2017
# 2                                    The Fantasticks        0       2000
# 3                     Karobaar: The Business of Love        0       2000
# 4                                            Glitter        0       2001
# ...                                              ...      ...        ...
# 9001                             Avant qu'on explose        0       2019
# 9002   Trinity Seven: Heavens Library & Crimson Lord        0       2019
# 9003                                  Out of Liberty        0       2019
# 9004                 Puffs: Filmed Live Off Broadway        0       2018
# 9005  Josh Groban Bridges from Madison Square Garden        0       2019
#
#       runtimeMinutes                   genres  avrg_rating  num_votes  \
# 0              118.0   Comedy,Fantasy,Romance          6.4    75863.0
# 1               80.0     Comedy,Drama,Fantasy          6.6      209.0
# 2               86.0          Musical,Romance          5.6     1086.0
# 3              180.0            Drama,Romance          4.5      211.0
# 4              104.0      Drama,Music,Romance          2.2    21033.0
# ...              ...                      ...          ...        ...
# 9001           108.0                   Comedy          6.6       80.0
# 9002            63.0  Action,Animation,Comedy          6.8       64.0
# 9003           111.0            Drama,Western          4.5      213.0
# 9004           118.0         Adventure,Comedy          8.6       17.0
# 9005             NaN                       \N          6.9        7.0
#
#                                                   Title  Year  Worldwide  \
# 0                                        Kate & Leopold  2001   76019048
# 1                              The Wandering Soap Opera  2019       3624
# 2                                       The Fantasticks  2000      49666
# 3                        Karobaar: The Business of Love  2000      45200
# 4                                               Glitter  2001    5271666
# ...                                                 ...   ...        ...
# 9001                                Avant qu'on explose  2019     119894
# 9002  Trinity Seven The Movie 2: Heavens Library & C...  2019      15712
# 9003                                     Out of Liberty  2019     265279
# 9004                    Puffs: Filmed Live Off Broadway  2018     464483
# 9005     Josh Groban Bridges from Madison Square Garden  2019     315173
#
#         Domestic
# 0     47121859.0
# 1         3624.0
# 2        49666.0
# 3        45200.0
# 4      4274407.0
# ...          ...
# 9001    119894.0
# 9002     15712.0
# 9003    265279.0
# 9004    464483.0
# 9005    315173.0
#
# [9006 rows x 14 columns]
